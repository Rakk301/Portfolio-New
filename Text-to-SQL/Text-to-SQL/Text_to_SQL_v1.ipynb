# %% [markdown]
# # Imports

# %%
# %%capture

# !pip install langchain
# !pip install langchain-community
# !pip install -U langchain-google-vertexai

# !pip install google-api-core
# !pip install google-auth
# !pip install google-cloud-aiplatform
# !pip install google-cloud-bigquery
# !pip install google-cloud-bigquery-storage
# !pip install google-cloud-core
# !pip install google-cloud-resource-manager
# !pip install google-cloud-storage
# !pip install google-crc32c
# !pip install google-resumable-media
# !pip install googleapis-common-protos

# %%
from langchain.prompts.chat import SystemMessagePromptTemplate
from langchain.prompts.chat import HumanMessagePromptTemplate
from langchain.prompts.chat import AIMessagePromptTemplate
from langchain.prompts.chat import ChatPromptTemplate
from langchain_google_vertexai import ChatVertexAI
from google.cloud import bigquery
import pandas as pd
import logging
import os

# %% [markdown]
# # initial Setup:

# %%
SERVICE_ACCOUNT_CREDENTIALS = '/content/text-sql-project-ServiceAccountKey.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = SERVICE_ACCOUNT_CREDENTIALS

# %%
DB_overview_file_path = '/content/Northwind_DB_Overview.txt'
schema_file_path = '/content/Nortwind_DB_Schema.txt'
relationships_file_path = '/content/Nortwind_DB_Relationships.txt'
tables_descriptions_file_path = '/content/Nortwind_DB_Table_Descriptions.txt'


with open(DB_overview_file_path, 'r') as file:
     db_overview = file.read()

with open(schema_file_path, 'r') as file:
     schema= file.read()

with open(relationships_file_path, 'r') as file:
     relationships = file.read()

with open(tables_descriptions_file_path, 'r') as file:
     table_fields_descriptions = file.read()

# %%
schema
# Out:
# 'Northwind Traders Database Schema:\n\n1. Products\nProductID: int, Primary Key, Not Null\nProductName: nvarchar(40), Not Null\nSupplierID: int, Foreign Key (Suppliers.SupplierID), Nullable\nCategoryID: int, Foreign Key (Categories.CategoryID), Nullable\nQuantityPerUnit: nvarchar(20), Nullable (Packaging details)\nUnitPrice: money, Nullable (Price per unit)\nUnitsInStock: smallint, Nullable (Current stock level)\nUnitsOnOrder: smallint, Nullable (Units currently on order)\nReorderLevel: smallint, Nullable (Threshold for reorder)\nDiscontinued: bit, Not Null (Whether the product is discontinued)\n\n\n2. Suppliers\nSupplierID: int, Primary Key, Not Null\nCompanyName: nvarchar(40), Not Null (Supplier’s company name)\nContactName: nvarchar(30), Nullable (Supplier’s contact person)\nContactTitle: nvarchar(30), Nullable (Title of the contact person)\nAddress: nvarchar(60), Nullable (Street address)\nCity: nvarchar(15), Nullable (City of the supplier)\nRegion: nvarchar(15), Nullable (Region of the supplier)\nPostalCode: nvarchar(10), Nullable\nCountry: nvarchar(15), Nullable (Supplier’s country)\nPhone: nvarchar(24), Nullable\nFax: nvarchar(24), Nullable\nHomePage: ntext, Nullable (Supplier’s website)\n\n3. Categories\nCategoryID: int, Primary Key, Not Null\nCategoryName: nvarchar(15), Not Null (Product category name)\nDescription: ntext, Nullable (Category description)\nPicture: image, Nullable (Category image)\n\n4. Orders\nOrderID: int, Primary Key, Not Null\nCustomerID: nchar(5), Foreign Key (Customers.CustomerID), Not Null\nEmployeeID: int, Foreign Key (Employees.EmployeeID), Nullable (Sales representative handling the order)\nOrderDate: datetime, Nullable (Date the order was placed)\nRequiredDate: datetime, Nullable (Date by which the customer requires the order)\nShippedDate: datetime, Nullable (Date the order was shipped)\nShipVia: int, Foreign Key (Shippers.ShipperID), Nullable (Shipping method)\nFreight: money, Nullable (Freight cost)\nShipName: nvarchar(40), Nullable (Shipping recipient name)\nShipAddress: nvarchar(60), Nullable\nShipCity: nvarchar(15), Nullable\nShipRegion: nvarchar(15), Nullable\nShipPostalCode: nvarchar(10), Nullable\nShipCountry: nvarchar(15), Nullable\n\n5. OrderDetails\nOrderID: int, Foreign Key (Orders.OrderID), Primary Key, Not Null\nProductID: int, Foreign Key (Products.ProductID), Primary Key, Not Null\nUnitPrice: money, Not Null (Price at the time of order)\nQuantity: smallint, Not Null (Number of units ordered)\nDiscount: real, Not Null (Discount applied to the order)\n\n6. Employees\nEmployeeID: int, Primary Key, Not Null\nLastName: nvarchar(20), Not Null\nFirstName: nvarchar(10), Not Null\nTitle: nvarchar(30), Nullable (Job title)\nTitleOfCourtesy: nvarchar(25), Nullable (e.g., Mr., Mrs., Dr.)\nBirthDate: datetime, Nullable\nHireDate: datetime, Nullable\nAddress: nvarchar(60), Nullable\nCity: nvarchar(15), Nullable\nRegion: nvarchar(15), Nullable\nPostalCode: nvarchar(10), Nullable\nCountry: nvarchar(15), Nullable\nHomePhone: nvarchar(24), Nullable\nExtension: nvarchar(4), Nullable\nPhoto: image, Nullable\nNotes: ntext, Nullable (Additional employee information)\nReportsTo: int, Nullable (Manager’s EmployeeID)\nPhotoPath: nvarchar(255), Nullable (Link to employee photo)\n\n7. Customers\nCustomerID: nchar(5), Primary Key, Not Null\nCompanyName: nvarchar(40), Not Null (Customer’s company name)\nContactName: nvarchar(30), Nullable (Customer’s contact person)\nContactTitle: nvarchar(30), Nullable (Title of the contact person)\nAddress: nvarchar(60), Nullable\nCity: nvarchar(15), Nullable\nRegion: nvarchar(15), Nullable\nPostalCode: nvarchar(10), Nullable\nCountry: nvarchar(15), Nullable\nPhone: nvarchar(24), Nullable\nFax: nvarchar(24), Nullable\n\n8. Shippers\nShipperID: int, Primary Key, Not Null\nCompanyName: nvarchar(40), Not Null (Shipping company name)\nPhone: nvarchar(24), Nullable\n\n9. EmployeeTerritories\nEmployeeID: int, Foreign Key (Employees.EmployeeID), Primary Key, Not Null\nTerrit ...

# %%
PROJECT = 'text-sql-project'

llm = ChatVertexAI(project = PROJECT,
                   model_name='gemini-1.5-flash-002',
                   temperature=0.0,
                   max_tokens=None,
                   max_retries=2)

# %%
user_query = "What's the total sales amount for each month in 2023?"

# %% [markdown]
# # Text - to - SQL:

# %% [markdown]
# ### STEP 1: Intent classification of user's text query:

# %%
intent_examples = pd.read_csv('/content/prompts_and_intents.csv')
intent_examples[:10]
# Out:
#                                               Prompt  \
# 0  Show me all orders placed by customer "Alfreds...
# 1  I need the list of orders from "Around the Hor...
# 2  Can you retrieve orders made by "Berglunds sna...
# 3  Fetch all orders for "Blauer See Delikatessen"...
# 4  Give me the orders from "Bon app'" in the last...
# 5        Who are our top 5 customers by total sales?
# 6  List the customers with the highest order valu...
# 7  Which customers have spent the most with us in...
# 8  Show me the top 10 customers in terms of total...
# 9  Find out which customers generated the most re...
#
#                                  Intent
# 0  RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 1  RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 2  RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 3  RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 4  RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 5       IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 6       IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 7       IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 8       IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 9       IDENTIFY_TOP_CUSTOMERS_BY_SALES

# %%
# Create prompt template and append system message, few shot examples and user query:
intent_messages = []

# System prompt:
template = "You are a helpful assistant capable of detecting the intent behind a user's query."
system_message_prompt = SystemMessagePromptTemplate.from_template(template)
intent_messages.append(system_message_prompt)

# %%
# Adding intro th
few_shot_intro = "The following are few-shot examples of user's queries being intent classified. Use these as guidelines to classify the intent of the user's query."
system_message_few_shot_intro = SystemMessagePromptTemplate.from_template(few_shot_intro)
few_shot_tail = "x-----------------------------------x"
system_message_few_shot_tail = SystemMessagePromptTemplate.from_template(few_shot_tail)
intent_messages.append(system_message_few_shot_intro)
intent_messages
# Out:
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="You are a helpful assistant capable of detecting the intent behind a user's query."), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="The following are few-shot examples of user's queries being intent classified. Use these as guidelines to classify the intent of the user's query."), additional_kwargs={})]

# %%
# Iterate through csv of few-shot examples to append to prompt template:
for _, row in intent_examples.iterrows():
    prompt, completion = row
    human_message = HumanMessagePromptTemplate.from_template(f"User: {prompt}")
    intent_messages.append(human_message)
    ai_message = AIMessagePromptTemplate.from_template(f"Assistant: {completion}")
    intent_messages.append(ai_message)
intent_messages.append(system_message_few_shot_tail)
intent_messages
# Out:
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="You are a helpful assistant capable of detecting the intent behind a user's query."), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="The following are few-shot examples of user's queries being intent classified. Use these as guidelines to classify the intent of the user's query."), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me all orders placed by customer "Alfreds Futterkiste" in September 2023.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: I need the list of orders from "Around the Horn" during the month of August.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Can you retrieve orders made by "Berglunds snabbköp" after July 1st, 2023?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Fetch all orders for "Blauer See Delikatessen" between June and August 2023.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Give me the orders from "Bon app\'" in the last quarter.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Who are our top 5 customers by total sales?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List the customers with the highest order values this year.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which customers have spent the most with us in 2023?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me the top 10 customers in terms of total purchase amount.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find out which customers generated the most revenue for us.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="User: What's the total sales amount for each month in 2023?"), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Provide a monthly breakdown of total sales for the current year.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: How much did we sell in each month of 2023?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me the total sales figures per month for this year.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="User: I'd like to see our monthly sales totals for 2023."), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: In which month did we ship the most orders in 2023?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: When was our busiest shipping period this year?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Identify the months with the highest number of shipments.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which month had the greatest number of orders shipped?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find out during which period we shipped the most products.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: How many products do we have in each category?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Provide a count of products grouped by their category.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List the number of products in each product category.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Can you show me how many items are in each category?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Give me a breakdown of product counts per category.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which products are currently out of stock?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List all items that have zero units in stock.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me the products that are not available right now.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find the products that are out of inventory.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: What products are we currently sold out of?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Who are the employees working in the Seattle region?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me all employees located in London.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Provide a list of employees by their region.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which employees are assigned to the Eastern region?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List employees along with the regions they cover.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Give me contact details for the supplier "Exotic Liquids".'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: I need the address of "Tokyo Traders".'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me the suppliers based in the USA.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List all suppliers along with their contact names and phone numbers.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Who supplies "Aniseed Syrup" and how can we contact them?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which products have been discontinued?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me all items that are no longer available for sale.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List the discontinued products from our inventory.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find products marked as discontinued.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: What products have we stopped selling?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which products have stock levels below their reorder point?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me items that need to be reordered.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List products where units in stock are less than the reorder level.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Identify products with low inventory levels.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: What products are running low in stock?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='x-----------------------------------x'), additional_kwargs={})]

# %%
human_template = "User: {user_query}"
human_message = HumanMessagePromptTemplate.from_template(human_template)
intent_messages.append(human_message)

# %%
intent_messages
# Out:
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="You are a helpful assistant capable of detecting the intent behind a user's query."), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="The following are few-shot examples of user's queries being intent classified. Use these as guidelines to classify the intent of the user's query."), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me all orders placed by customer "Alfreds Futterkiste" in September 2023.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: I need the list of orders from "Around the Horn" during the month of August.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Can you retrieve orders made by "Berglunds snabbköp" after July 1st, 2023?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Fetch all orders for "Blauer See Delikatessen" between June and August 2023.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Give me the orders from "Bon app\'" in the last quarter.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Who are our top 5 customers by total sales?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List the customers with the highest order values this year.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which customers have spent the most with us in 2023?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me the top 10 customers in terms of total purchase amount.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find out which customers generated the most revenue for us.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="User: What's the total sales amount for each month in 2023?"), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Provide a monthly breakdown of total sales for the current year.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: How much did we sell in each month of 2023?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me the total sales figures per month for this year.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="User: I'd like to see our monthly sales totals for 2023."), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: In which month did we ship the most orders in 2023?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: When was our busiest shipping period this year?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Identify the months with the highest number of shipments.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which month had the greatest number of orders shipped?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find out during which period we shipped the most products.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: How many products do we have in each category?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Provide a count of products grouped by their category.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List the number of products in each product category.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Can you show me how many items are in each category?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Give me a breakdown of product counts per category.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which products are currently out of stock?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List all items that have zero units in stock.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me the products that are not available right now.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find the products that are out of inventory.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: What products are we currently sold out of?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Who are the employees working in the Seattle region?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me all employees located in London.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Provide a list of employees by their region.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which employees are assigned to the Eastern region?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List employees along with the regions they cover.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Give me contact details for the supplier "Exotic Liquids".'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: I need the address of "Tokyo Traders".'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me the suppliers based in the USA.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List all suppliers along with their contact names and phone numbers.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Who supplies "Aniseed Syrup" and how can we contact them?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which products have been discontinued?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me all items that are no longer available for sale.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List the discontinued products from our inventory.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find products marked as discontinued.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: What products have we stopped selling?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which products have stock levels below their reorder point?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me items that need to be reordered.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List products where units in stock are less than the reorder level.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Identify products with low inventory levels.'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: What products are running low in stock?'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='x-----------------------------------x'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['user_query'], input_types={}, partial_variables={}, template='User: {user_query}'), additional_kwargs={})]

# %%
chat_prompt = ChatPromptTemplate.from_messages(intent_messages)

# Format the prompt with the user's query and generate the message sequence
request = chat_prompt.format_prompt(user_query=user_query).to_messages()

# %%
# %%time

response = llm(request)
intent = response.content.strip()
# Out:
# CPU times: user 18.9 ms, sys: 4.29 ms, total: 23.2 ms
# Wall time: 306 ms

# %%
intent
# Out:
# 'Assistant: CALCULATE_TOTAL_SALES_PER_MONTH'

# %% [markdown]
# ### STEP 2: Entity extraction from the user's text query:

# %%
NER_examples = pd.read_csv('/content/prompts_NER.csv')
NER_examples[:10]
# Out:
#                                               Prompt  \
# 0  Show me all orders shipped to Germany between ...
# 1  List all products supplied by Exotic Liquids t...
# 2  Who are the customers from London who have pla...
# 3         Find employees who report to Andrew Fuller
# 4         Get me a list of all discontinued products
# 5  Which products are in the Beverages category a...
# 6  Show orders that were shipped via Speedy Expre...
# 7   List all employees hired after January 1st, 2020
# 8  Which customers have not placed any orders in ...
# 9             Find the top 5 most expensive products
#
#                                             Entities
# 0  Ship Country: Germany | Start Date: January 1s...
# 1  Supplier Name: Exotic Liquids | Units In Stock...
# 2     Customer City: London | Order Date: Last month
# 3  Manager Name: Andrew Fuller | Relationship: Re...
# 4                    Discontinued Status: Yes (True)
# 5  Category Name: Beverages | Unit Price: Greater...
# 6  Shipper Name: Speedy Express | Ship Date: Dece...
# 7                 Hire Date: After January 1st, 2020
# 8  Time Frame: Past year | Order Count: Zero (No ...
# 9     Order By: Unit Price descending | Limit: Top 5

# %%
entity_messages =[]

template = "You are a helpful assistant capable of performing named entity recognition."
system_message_prompt = SystemMessagePromptTemplate.from_template(template)
entity_messages.append(system_message_prompt)

# %%
# Adding intro th
few_shot_intro = "The following are few-shot examples where entities are being extracted from the user's queries. Use these as guidelines to extract the entities from the user's query."
system_message_few_shot_intro = SystemMessagePromptTemplate.from_template(few_shot_intro)
few_shot_tail = "x-----------------------------------x"
system_message_few_shot_tail = SystemMessagePromptTemplate.from_template(few_shot_tail)
entity_messages.append(system_message_few_shot_intro)
entity_messages
# Out:
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant capable of performing named entity recognition.'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="The following are few-shot examples where entities are being extracted from the user's queries. Use these as guidelines to extract the entities from the user's query."), additional_kwargs={})]

# %%
# Iterate through csv of few-shot examples to append to prompt template:
for _, row in NER_examples.iterrows():
    prompt, completion = row
    human_message = HumanMessagePromptTemplate.from_template(f"User: {prompt}")
    entity_messages.append(human_message)
    ai_message = AIMessagePromptTemplate.from_template(f"Assistant: {completion}")
    entity_messages.append(ai_message)
entity_messages.append(system_message_few_shot_tail)
entity_messages
# Out:
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant capable of performing named entity recognition.'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="The following are few-shot examples where entities are being extracted from the user's queries. Use these as guidelines to extract the entities from the user's query."), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me all orders shipped to Germany between January 1st, 2023, and March 31st, 2023'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Ship Country: Germany | Start Date: January 1st, 2023 | End Date: March 31st, 2023'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List all products supplied by Exotic Liquids that are currently out of stock'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Supplier Name: Exotic Liquids | Units In Stock: 0 (Out of Stock)'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Who are the customers from London who have placed orders in the last month'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Customer City: London | Order Date: Last month'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find employees who report to Andrew Fuller'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Manager Name: Andrew Fuller | Relationship: Reports To'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Get me a list of all discontinued products'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Discontinued Status: Yes (True)'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which products are in the Beverages category and cost more than $20 per unit'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Category Name: Beverages | Unit Price: Greater than $20'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show orders that were shipped via Speedy Express in December 2022'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Shipper Name: Speedy Express | Ship Date: December 2022'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List all employees hired after January 1st, 2020'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Hire Date: After January 1st, 2020'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which customers have not placed any orders in the past year'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Time Frame: Past year | Order Count: Zero (No orders)'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find the top 5 most expensive products'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Order By: Unit Price descending | Limit: Top 5'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: How many orders were placed by the customer with CustomerID ALFKI'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Customer ID: ALFKI | Calculation: Count of Orders'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Retrieve all orders containing the product Chai'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Product Name: Chai'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Get the total sales amount for orders shipped to France in 2023'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Ship Country: France | Year: 2023 | Calculation: Total Sales Amount'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me the list of suppliers located in the USA'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Supplier Country: USA'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which products need to be reordered'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Condition: Units In Stock less than Reorder Level'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List the customers who have purchased products from the Seafood category'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Category Name: Seafood | Customer Action: Purchased products in this category'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find orders placed between March 1st and March 31st, 2023, sorted by order date'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Start Date: March 1st, 2023 | End Date: March 31st, 2023 | Order By: Order Date ascending'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Get a list of employees with the title Sales Representative'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Job Title: Sales Representative'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show all customers located in the Eastern region'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Region Description: Eastern | Entity Type: Customers'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find the average unit price of products in the Confections category'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Category Name: Confections | Calculation: Average Unit Price'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List orders where the shipped date is after the required date'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Condition: Shipped Date greater than Required Date'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which employees are not assigned to any territories'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Employee Territory Assignment: None'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show the total number of orders handled by Nancy Davolio'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Employee Name: Nancy Davolio | Calculation: Total Orders Handled'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find all shippers with phone numbers starting with 503'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Phone Number Prefix: 503 | Entity Type: Shippers'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Get the names of customers who have ordered both Chang and Aniseed Syrup'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Product Names: Chang, Aniseed Syrup | Customer Action: Ordered both products'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: List the top 3 categories with the highest number of products'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Calculation: Product Count per Category | Order By: Product Count descending | Limit: Top 3'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Find suppliers who supply products in both Seafood and Produce categories'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Categories: Seafood, Produce | Supplier Action: Supplies products in both categories'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Retrieve orders with a total discount greater than 10%'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Calculation: Total Discount per Order greater than 10%'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Which employees have birthdays this month'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Birth Date: Month equals current month'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Show me all orders where the freight cost exceeds $100'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Freight Cost: Greater than $100'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='x-----------------------------------x'), additional_kwargs={})]

# %%
human_template = "User: {user_query}"
human_message = HumanMessagePromptTemplate.from_template(human_template)
entity_messages.append(human_message)

# %%
chat_prompt = ChatPromptTemplate.from_messages(entity_messages)

# Format the prompt with the user's query and generate the message sequence
request = chat_prompt.format_prompt(user_query=user_query).to_messages()

# %%
# %%time

response = llm(request)
entities = response.content.strip()
# Out:
# CPU times: user 18.4 ms, sys: 3.03 ms, total: 21.5 ms
# Wall time: 343 ms

# %%
entities
# Out:
# 'Assistant: Year: 2023 | Calculation: Total Sales Amount per Month'

# %% [markdown]
# ### STEP 3: Mapping query and intent to relevant tables in the database:

# %%
mapping_examples = pd.read_csv('/content/Intents_table_mapping.csv')
mapping_examples[:10]
# Out:
#                                               Query   \
# 0  Show me all orders placed by customer "Alfreds...
# 1  Show me the top 10 customers in terms of total...
# 2  Show me the total sales figures per month for ...
# 3  Which month had the greatest number of orders ...
# 4  Provide a count of products grouped by their c...
# 5      List all items that have zero units in stock.
# 6           Show me all employees located in London.
# 7  List all suppliers along with their contact na...
# 8              Find products marked as discontinued.
# 9  List products where units in stock are less th...
#
#                                  Intent  \
# 0  RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 1       IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 2       CALCULATE_TOTAL_SALES_PER_MONTH
# 3            FIND_PEAK_SHIPMENT_PERIODS
# 4  GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY
# 5        IDENTIFY_OUT_OF_STOCK_PRODUCTS
# 6              LIST_EMPLOYEES_BY_REGION
# 7              GET_SUPPLIER_INFORMATION
# 8            FIND_DISCONTINUED_PRODUCTS
# 9          FIND_PRODUCTS_WITH_LOW_STOCK
#
#                                        Mapped_Tables
# 0                                 Orders | Customers
# 1                 Orders | Order Details | Customers
# 2                             Orders | Order Details
# 3                                             Orders
# 4                              Products | Categories
# 5                                           Products
# 6  Employees | EmployeeTerritories | Territories ...
# 7                                          Suppliers
# 8                                           Products
# 9                                           Products

# %%
# Create prompt template and append system message, few shot examples and user query:
mapping_messages = []

# System prompt:
template = "You are a helpful assistant capable of mapping detected intent to the correct list of tables from a database. You will be provided with a schema of the database and a detailed explanation of the databases tables and individual fields, which you must use to properly map the intent."
system_message_prompt = SystemMessagePromptTemplate.from_template(template)
mapping_messages.append(system_message_prompt)

# %%
schema_intro = "Here is the schema of the database and descriptions of its tables and fields to help you understand the structure:"
system_message_schema_intro = SystemMessagePromptTemplate.from_template(schema_intro)
mapping_messages.append(system_message_schema_intro)

# Assuming 'schema' and 'table_fields_descriptions' contain the relevant details
system_message_schema = SystemMessagePromptTemplate.from_template(schema)
system_message_table_fields_descriptions = SystemMessagePromptTemplate.from_template(table_fields_descriptions)

# Append schema and table descriptions to messages
mapping_messages.append(system_message_schema)
mapping_messages.append(system_message_table_fields_descriptions)

# %%
# Adding intro th
few_shot_intro = "The following are few-shot examples of intents being mapped to relavant tables. Use these as guidelines to map the intent to the relevant table(s)."
system_message_few_shot_intro = SystemMessagePromptTemplate.from_template(few_shot_intro)
few_shot_tail = "x-----------------------------------x"
system_message_few_shot_tail = SystemMessagePromptTemplate.from_template(few_shot_tail)
mapping_messages.append(system_message_few_shot_intro)
mapping_messages
# Out:
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant capable of mapping detected intent to the correct list of tables from a database. You will be provided with a schema of the database and a detailed explanation of the databases tables and individual fields, which you must use to properly map the intent.'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Here is the schema of the database and descriptions of its tables and fields to help you understand the structure:'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Northwind Traders Database Schema:\n\n1. Products\nProductID: int, Primary Key, Not Null\nProductName: nvarchar(40), Not Null\nSupplierID: int, Foreign Key (Suppliers.SupplierID), Nullable\nCategoryID: int, Foreign Key (Categories.CategoryID), Nullable\nQuantityPerUnit: nvarchar(20), Nullable (Packaging details)\nUnitPrice: money, Nullable (Price per unit)\nUnitsInStock: smallint, Nullable (Current stock level)\nUnitsOnOrder: smallint, Nullable (Units currently on order)\nReorderLevel: smallint, Nullable (Threshold for reorder)\nDiscontinued: bit, Not Null (Whether the product is discontinued)\n\n\n2. Suppliers\nSupplierID: int, Primary Key, Not Null\nCompanyName: nvarchar(40), Not Null (Supplier’s company name)\nContactName: nvarchar(30), Nullable (Supplier’s contact person)\nContactTitle: nvarchar(30), Nullable (Title of the contact person)\nAddress: nvarchar(60), Nullable (Street address)\nCity: nvarchar(15), Nullable (City of the supplier)\nRegion: nvarchar(15), Nullable (Region of the supplier)\nPostalCode: nvarchar(10), Nullable\nCountry: nvarchar(15), Nullable (Supplier’s country)\nPhone: nvarchar(24), Nullable\nFax: nvarchar(24), Nullable\nHomePage: ntext, Nullable (Supplier’s website)\n\n3. Categories\nCategoryID: int, Primary Key, Not Null\nCategoryName: nvarchar(15), Not Null (Product category name)\nDescription: ntext, Nullable (Category description)\nPicture: image, Nullable (Category image)\n\n4. Orders\nOrderID: int, Primary Key, Not Null\nCustomerID: nchar(5), Foreign Key (Customers.CustomerID), Not Null\nEmployeeID: int, Foreign Key (Employees.EmployeeID), Nullable (Sales representative handling the order)\nOrderDate: datetime, Nullable (Date the order was placed)\nRequiredDate: datetime, Nullable (Date by which the customer requires the order)\nShippedDate: datetime, Nullable (Date the order was shipped)\nShipVia: int, Foreign Key (Shippers.ShipperID), Nullable (Shipping method)\nFreight: money, Nullable (Freight cost)\nShipName: nvarchar(40), Nullable (Shipping recipient name)\nShipAddress: nvarchar(60), Nullable\nShipCity: nvarchar(15), Nullable\nShipRegion: nvarchar(15), Nullable\nShipPostalCode: nvarchar(10), Nullable\nShipCountry: nvarchar(15), Nullable\n\n5. OrderDetails\nOrderID: int, Foreign Key (Orders.OrderID), Primary Key, Not Null\nProductID: int, Foreign Key (Products.ProductID), Primary Key, Not Null\nUnitPrice: money, Not Null (Price at the time of order)\nQuantity: smallint, Not Null (Number of units ordered)\nDiscount: real, Not Null (Discount applied to the order)\n\n6. Employees\nEmployeeID: int, Primary Key, Not Null\nLastName: nvarchar(20), Not Null\nFirstName: nvarchar(10), Not Null\nTitle: nvarchar(30), Nullable (Job title)\nTitleOfCourtesy: nvarchar(25), Nullable (e.g., Mr., Mrs., Dr.)\nBirthDate: datetime, Nullable\nHireDate: datetime, Nullable\nAddress: nvarchar(60), Nullable\nCity: nvarchar(15), Nullable\nRegion: nvarchar(15), Nullable\nPostalCode: nvarchar(10), Nullable\nCountry: nvarchar(15), Nullable\nHomePhone: nvarchar(24), Nullable\nExtension: nvarchar(4), Nullable\nPhoto: image, Nullable\nNotes: ntext, Nullable (Additional employee information)\nReportsTo: int, Nullable (Manager’s EmployeeID)\nPhotoPath: nvarchar(255), Nullable (Link to employee photo)\n\n7. Customers\nCustomerID: nchar(5), Primary Key, Not Null\nCompanyName: nvarchar(40), Not Null (Customer’s company name)\nContactName: nvarchar(30), Nullable (Customer’s contact person)\nContactTitle: nvarchar(30), Nullable (Title of the contact person)\nAddress: nvarchar(60), Nullable\nCity: nvarchar(15), Nullable\nRegion: nvarchar(15), Nullable\nPostalCode: nvarchar(10), Nullable\nCountry: nvarchar(15), Nullable\nPhone: nvarchar(24), Nullable\nFax: nvarchar(24), Nullable\n\n8. Shippers\nShipperID: int, Primary Key, Not Null\nCompanyName: nvarchar(40), Not Null (Shipping company name)\nPhone: nvarchar(24),  ...
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Table and Field Descriptions:\n\n1. **Products Table**\n   Purpose: Stores information about the products that Northwind sells.\n   Columns:\n   - ProductID: A unique identifier for each product. This acts as the primary key.\n   - ProductName: The name of the product.\n   - SupplierID: A foreign key linking the product to its supplier from the Suppliers table.\n   - CategoryID: A foreign key linking the product to a category in the Categories table.\n   - QuantityPerUnit: Describes how the product is packaged (e.g., "24 cans per box").\n   - UnitPrice: The price per unit for the product.\n   - UnitsInStock: The current stock level for the product.\n   - UnitsOnOrder: Quantity of the product that has been ordered but not yet received.\n   - ReorderLevel: The stock level at which more product should be reordered.\n   - Discontinued: A Boolean value indicating whether the product is still available for sale.\n\n2. **Suppliers Table**\n   Purpose: Contains details about the suppliers who provide the products sold by Northwind.\n   Columns:\n   - SupplierID: A unique identifier for each supplier. This acts as the primary key.\n   - CompanyName: The name of the supplier company.\n   - ContactName: The name of the contact person at the supplier.\n   - ContactTitle: The job title of the contact person.\n   - Address, City, Region, PostalCode, Country: Details about the supplier’s location.\n   - Phone, Fax: Contact numbers for the supplier.\n   - HomePage: The website URL for the supplier.\n\n3. **Categories Table**\n   Purpose: Categorizes products into different types, allowing for better organization and querying.\n   Columns:\n   - CategoryID: A unique identifier for each category. This acts as the primary key.\n   - CategoryName: The name of the category (e.g., "Beverages").\n   - Description: A textual description of the category.\n   - Picture: An image representing the category (optional).\n\n4. **Orders Table**\n   Purpose: Records customer orders placed with Northwind.\n   Columns:\n   - OrderID: A unique identifier for each order. This acts as the primary key.\n   - CustomerID: A foreign key linking the order to the Customers table.\n   - EmployeeID: A foreign key linking the order to the employee who handled the order.\n   - OrderDate: The date when the order was placed.\n   - RequiredDate: The date by which the customer needs the order delivered.\n   - ShippedDate: The date when the order was shipped to the customer.\n   - ShipVia: A foreign key linking to the shipping service (from the Shippers table).\n   - Freight: The shipping cost for the order.\n   - ShipName, ShipAddress, ShipCity, ShipRegion, ShipPostalCode, ShipCountry: Details of the destination for the order.\n\n5. **Order Details Table**\n   Purpose: Contains specific details about the products within each order.\n   Columns:\n   - OrderID: A foreign key linking to the Orders table.\n   - ProductID: A foreign key linking to the Products table.\n   - UnitPrice: The price per unit at the time of the order.\n   - Quantity: The number of units of the product ordered.\n   - Discount: The discount applied to the product in the order.\n\n6. **Employees Table**\n   Purpose: Stores details about the employees working at Northwind.\n   Columns:\n   - EmployeeID: A unique identifier for each employee. This acts as the primary key.\n   - LastName, FirstName: Employee\'s name.\n   - Title, TitleOfCourtesy: Job title and courtesy title (e.g., Mr., Mrs.).\n   - BirthDate, HireDate: Dates of birth and hire.\n   - Address, City, Region, PostalCode, Country: Location details of the employee.\n   - HomePhone, Extension: Contact details.\n   - Notes: Additional notes about the employee.\n   - ReportsTo: The EmployeeID of the person to whom this employee reports.\n   - Photo, PhotoPath: Image of the employee and its file path.\n\n7. **Customers Table**\n   Purpos ...
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='The following are few-shot examples of intents being mapped to relavant tables. Use these as guidelines to map the intent to the relevant table(s).'), additional_kwargs={})]

# %%
for _, row in mapping_examples.iterrows():
    row_query = row['Query ']
    row_intent = row['Intent']
    row_table_mapping = row['Mapped_Tables']

    # Format and append user message (Query and Intent)
    human_message = HumanMessagePromptTemplate.from_template(f"User: Query: {row_query}, Intent: {row_intent}")
    mapping_messages.append(human_message)

    # Format and append assistant message (table_mapping)
    ai_message = AIMessagePromptTemplate.from_template(f"Assistant: Mapped Tables: {row_table_mapping}")
    mapping_messages.append(ai_message)

# Append few-shot tail at the end
mapping_messages.append(system_message_few_shot_tail)
mapping_messages
# Out:
# [SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a helpful assistant capable of mapping detected intent to the correct list of tables from a database. You will be provided with a schema of the database and a detailed explanation of the databases tables and individual fields, which you must use to properly map the intent.'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Here is the schema of the database and descriptions of its tables and fields to help you understand the structure:'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Northwind Traders Database Schema:\n\n1. Products\nProductID: int, Primary Key, Not Null\nProductName: nvarchar(40), Not Null\nSupplierID: int, Foreign Key (Suppliers.SupplierID), Nullable\nCategoryID: int, Foreign Key (Categories.CategoryID), Nullable\nQuantityPerUnit: nvarchar(20), Nullable (Packaging details)\nUnitPrice: money, Nullable (Price per unit)\nUnitsInStock: smallint, Nullable (Current stock level)\nUnitsOnOrder: smallint, Nullable (Units currently on order)\nReorderLevel: smallint, Nullable (Threshold for reorder)\nDiscontinued: bit, Not Null (Whether the product is discontinued)\n\n\n2. Suppliers\nSupplierID: int, Primary Key, Not Null\nCompanyName: nvarchar(40), Not Null (Supplier’s company name)\nContactName: nvarchar(30), Nullable (Supplier’s contact person)\nContactTitle: nvarchar(30), Nullable (Title of the contact person)\nAddress: nvarchar(60), Nullable (Street address)\nCity: nvarchar(15), Nullable (City of the supplier)\nRegion: nvarchar(15), Nullable (Region of the supplier)\nPostalCode: nvarchar(10), Nullable\nCountry: nvarchar(15), Nullable (Supplier’s country)\nPhone: nvarchar(24), Nullable\nFax: nvarchar(24), Nullable\nHomePage: ntext, Nullable (Supplier’s website)\n\n3. Categories\nCategoryID: int, Primary Key, Not Null\nCategoryName: nvarchar(15), Not Null (Product category name)\nDescription: ntext, Nullable (Category description)\nPicture: image, Nullable (Category image)\n\n4. Orders\nOrderID: int, Primary Key, Not Null\nCustomerID: nchar(5), Foreign Key (Customers.CustomerID), Not Null\nEmployeeID: int, Foreign Key (Employees.EmployeeID), Nullable (Sales representative handling the order)\nOrderDate: datetime, Nullable (Date the order was placed)\nRequiredDate: datetime, Nullable (Date by which the customer requires the order)\nShippedDate: datetime, Nullable (Date the order was shipped)\nShipVia: int, Foreign Key (Shippers.ShipperID), Nullable (Shipping method)\nFreight: money, Nullable (Freight cost)\nShipName: nvarchar(40), Nullable (Shipping recipient name)\nShipAddress: nvarchar(60), Nullable\nShipCity: nvarchar(15), Nullable\nShipRegion: nvarchar(15), Nullable\nShipPostalCode: nvarchar(10), Nullable\nShipCountry: nvarchar(15), Nullable\n\n5. OrderDetails\nOrderID: int, Foreign Key (Orders.OrderID), Primary Key, Not Null\nProductID: int, Foreign Key (Products.ProductID), Primary Key, Not Null\nUnitPrice: money, Not Null (Price at the time of order)\nQuantity: smallint, Not Null (Number of units ordered)\nDiscount: real, Not Null (Discount applied to the order)\n\n6. Employees\nEmployeeID: int, Primary Key, Not Null\nLastName: nvarchar(20), Not Null\nFirstName: nvarchar(10), Not Null\nTitle: nvarchar(30), Nullable (Job title)\nTitleOfCourtesy: nvarchar(25), Nullable (e.g., Mr., Mrs., Dr.)\nBirthDate: datetime, Nullable\nHireDate: datetime, Nullable\nAddress: nvarchar(60), Nullable\nCity: nvarchar(15), Nullable\nRegion: nvarchar(15), Nullable\nPostalCode: nvarchar(10), Nullable\nCountry: nvarchar(15), Nullable\nHomePhone: nvarchar(24), Nullable\nExtension: nvarchar(4), Nullable\nPhoto: image, Nullable\nNotes: ntext, Nullable (Additional employee information)\nReportsTo: int, Nullable (Manager’s EmployeeID)\nPhotoPath: nvarchar(255), Nullable (Link to employee photo)\n\n7. Customers\nCustomerID: nchar(5), Primary Key, Not Null\nCompanyName: nvarchar(40), Not Null (Customer’s company name)\nContactName: nvarchar(30), Nullable (Customer’s contact person)\nContactTitle: nvarchar(30), Nullable (Title of the contact person)\nAddress: nvarchar(60), Nullable\nCity: nvarchar(15), Nullable\nRegion: nvarchar(15), Nullable\nPostalCode: nvarchar(10), Nullable\nCountry: nvarchar(15), Nullable\nPhone: nvarchar(24), Nullable\nFax: nvarchar(24), Nullable\n\n8. Shippers\nShipperID: int, Primary Key, Not Null\nCompanyName: nvarchar(40), Not Null (Shipping company name)\nPhone: nvarchar(24),  ...
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Table and Field Descriptions:\n\n1. **Products Table**\n   Purpose: Stores information about the products that Northwind sells.\n   Columns:\n   - ProductID: A unique identifier for each product. This acts as the primary key.\n   - ProductName: The name of the product.\n   - SupplierID: A foreign key linking the product to its supplier from the Suppliers table.\n   - CategoryID: A foreign key linking the product to a category in the Categories table.\n   - QuantityPerUnit: Describes how the product is packaged (e.g., "24 cans per box").\n   - UnitPrice: The price per unit for the product.\n   - UnitsInStock: The current stock level for the product.\n   - UnitsOnOrder: Quantity of the product that has been ordered but not yet received.\n   - ReorderLevel: The stock level at which more product should be reordered.\n   - Discontinued: A Boolean value indicating whether the product is still available for sale.\n\n2. **Suppliers Table**\n   Purpose: Contains details about the suppliers who provide the products sold by Northwind.\n   Columns:\n   - SupplierID: A unique identifier for each supplier. This acts as the primary key.\n   - CompanyName: The name of the supplier company.\n   - ContactName: The name of the contact person at the supplier.\n   - ContactTitle: The job title of the contact person.\n   - Address, City, Region, PostalCode, Country: Details about the supplier’s location.\n   - Phone, Fax: Contact numbers for the supplier.\n   - HomePage: The website URL for the supplier.\n\n3. **Categories Table**\n   Purpose: Categorizes products into different types, allowing for better organization and querying.\n   Columns:\n   - CategoryID: A unique identifier for each category. This acts as the primary key.\n   - CategoryName: The name of the category (e.g., "Beverages").\n   - Description: A textual description of the category.\n   - Picture: An image representing the category (optional).\n\n4. **Orders Table**\n   Purpose: Records customer orders placed with Northwind.\n   Columns:\n   - OrderID: A unique identifier for each order. This acts as the primary key.\n   - CustomerID: A foreign key linking the order to the Customers table.\n   - EmployeeID: A foreign key linking the order to the employee who handled the order.\n   - OrderDate: The date when the order was placed.\n   - RequiredDate: The date by which the customer needs the order delivered.\n   - ShippedDate: The date when the order was shipped to the customer.\n   - ShipVia: A foreign key linking to the shipping service (from the Shippers table).\n   - Freight: The shipping cost for the order.\n   - ShipName, ShipAddress, ShipCity, ShipRegion, ShipPostalCode, ShipCountry: Details of the destination for the order.\n\n5. **Order Details Table**\n   Purpose: Contains specific details about the products within each order.\n   Columns:\n   - OrderID: A foreign key linking to the Orders table.\n   - ProductID: A foreign key linking to the Products table.\n   - UnitPrice: The price per unit at the time of the order.\n   - Quantity: The number of units of the product ordered.\n   - Discount: The discount applied to the product in the order.\n\n6. **Employees Table**\n   Purpose: Stores details about the employees working at Northwind.\n   Columns:\n   - EmployeeID: A unique identifier for each employee. This acts as the primary key.\n   - LastName, FirstName: Employee\'s name.\n   - Title, TitleOfCourtesy: Job title and courtesy title (e.g., Mr., Mrs.).\n   - BirthDate, HireDate: Dates of birth and hire.\n   - Address, City, Region, PostalCode, Country: Location details of the employee.\n   - HomePhone, Extension: Contact details.\n   - Notes: Additional notes about the employee.\n   - ReportsTo: The EmployeeID of the person to whom this employee reports.\n   - Photo, PhotoPath: Image of the employee and its file path.\n\n7. **Customers Table**\n   Purpos ...
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='The following are few-shot examples of intents being mapped to relavant tables. Use these as guidelines to map the intent to the relevant table(s).'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: Show me all orders placed by customer "Alfreds Futterkiste" in September 2023., Intent: RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Orders | Customers'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: Show me the top 10 customers in terms of total purchase amount., Intent: IDENTIFY_TOP_CUSTOMERS_BY_SALES'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Orders | Order Details | Customers'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: Show me the total sales figures per month for this year., Intent: CALCULATE_TOTAL_SALES_PER_MONTH'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Orders | Order Details'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: Which month had the greatest number of orders shipped?, Intent: FIND_PEAK_SHIPMENT_PERIODS'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Orders'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: Provide a count of products grouped by their category., Intent: GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Products | Categories'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: List all items that have zero units in stock., Intent: IDENTIFY_OUT_OF_STOCK_PRODUCTS'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Products'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: Show me all employees located in London., Intent: LIST_EMPLOYEES_BY_REGION'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Employees | EmployeeTerritories | Territories | Region'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: List all suppliers along with their contact names and phone numbers., Intent: GET_SUPPLIER_INFORMATION'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Suppliers'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: Find products marked as discontinued., Intent: FIND_DISCONTINUED_PRODUCTS'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Products'), additional_kwargs={}),
#  HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='User: Query: List products where units in stock are less than the reorder level., Intent: FIND_PRODUCTS_WITH_LOW_STOCK'), additional_kwargs={}),
#  AIMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Assistant: Mapped Tables: Products'), additional_kwargs={}),
#  SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='x-----------------------------------x'), additional_kwargs={})]

# %%
human_template = "User: Query: {user_query}, Intent: {intent}"
human_message = HumanMessagePromptTemplate.from_template(human_template)
mapping_messages.append(human_message)

# %%
chat_prompt = ChatPromptTemplate.from_messages(mapping_messages)

# Format the prompt with the user's query and generate the message sequence
request = chat_prompt.format_prompt(user_query=user_query, intent= intent ).to_messages()

# %%
# %%time

response = llm(request)
mapping = response.content.strip()
# Out:
# CPU times: user 17.1 ms, sys: 0 ns, total: 17.1 ms
# Wall time: 350 ms

# %%
mapping
# Out:
# 'Assistant: Mapped Tables: Orders, Order Details'

# %% [markdown]
# ### STEP 4: Creating SQL Query :

# %%
query_creation_messages = []

template =  """
You are a SQL expert skilled in writing complex queries for BigQuery. You will be given a user's request in plain text, describing the data they need to extract from the database. Your task is to convert the user's text input into a valid SQL query to retrieve the relevant data from the database.

To help you construct accurate queries, you will be provided with:
- A detailed overview of the database, including its schema, relationships between the tables, and explanations of each table and its fields.
- The user's intent, extracted entities, and recommended tables based on their input.

"""

system_message_prompt = SystemMessagePromptTemplate.from_template(template)
query_creation_messages.append(system_message_prompt)

# %%
human_template = """Use this information to generate a correct SQL query that meets the user's requirements:

Northwind Traders Database Information:
--------------
Database Overview : {overview}\n
Database Schema : {schema}\n
Database Relationships : {relationships}
Detailed Descriptions of Tables and Fields : {descriptions}

User Query:
-----------
{user_query}


Input Parameters:
-----------------
INTENT: {intent}
EXTRACTED_ENTITIES: {entities}
RECOMMENDED_MAPPED_TABLES: {mapping}

NOTE : The database name in BigQuery is 'northwind_dataset'

"""

# %%
human_message = HumanMessagePromptTemplate.from_template(human_template)
query_creation_messages.append(human_message)

chat_prompt = ChatPromptTemplate.from_messages(query_creation_messages)

request = chat_prompt.format_prompt(intent=intent,
                                    entities=entities,
                                    mapping=mapping,
                                    user_query=user_query,
                                    overview = db_overview,
                                    schema = schema,
                                    relationships = relationships,
                                    descriptions = table_fields_descriptions).to_messages()

# %%
# %%time

query_generation_response = llm(request)
# Out:
# CPU times: user 26.6 ms, sys: 1.14 ms, total: 27.7 ms
# Wall time: 1.03 s

# %%
llm_response = query_generation_response.content
filtered_query = llm_response.strip().replace("sql", "").replace("", "").strip()
filtered_query = filtered_query.replace("`","")
print(filtered_query)
# Out:
# SELECT
#     strftime('%Y-%m', o.OrderDate) AS sales_month,
#     SUM(od.Quantity * od.UnitPrice * (
#       1 - od.Discount
#     )) AS total_sales
#   FROM
#     northwind_dataset.Orders AS o
#     INNER JOIN northwind_dataset.OrderDetails AS od ON o.OrderID = od.OrderID
#   WHERE strftime('%Y', o.OrderDate) = '2023'
#   GROUP BY 1
# ORDER BY
#   sales_month

# %%
client = bigquery.Client()


query_job = client.query(filtered_query)

# Get the result and display it
results = query_job.result()

df= results.to_dataframe()
df
# Out:
#      CategoryName  ProductCount
# 0       Beverages            48
# 1      Condiments            48
# 2     Confections            52
# 3  Dairy Products            40
# 4  Grains/Cereals            28
# 5    Meat/Poultry            24
# 6         Produce            20
# 7         Seafood            48

# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-5.0.2-py3-none-any.whl.metadata (15 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Collecting fastapi<1.0 (from gradio)
#   Downloading fastapi-0.115.2-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.4.0 (from gradio)
#   Downloading gradio_client-1.4.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.27.2)
# Collecting huggingface-hub>=0.25.1 (from gradio)
#   Downloading huggingface_hub-0.25.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.10.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio) (24.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.9.2)
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.0.2)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.6.9-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.12.5)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (4.12.2)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.31.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.4.0->gradio) (2024.6.1)
# Collecting websockets<13.0,>=10.0 (from gradio-client==1.4.0->gradio)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio) (1.2.2)
# Collecting starlette<0.41.0,>=0.37.2 (from fastapi<1.0->gradio)
#   Downloading starlette-0.39.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (3.16.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.25.1->gradio) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio) (2.23.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (13.9.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.18.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.25.1->gradio) (2.2.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-5.0.2-py3-none-any.whl (42.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 12.2 MB/s eta 0:00:00
# Downloading gradio_client-1.4.0-py3-none-any.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 16.9 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading fastapi-0.115.2-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 7.1 MB/s eta 0:00:00
# Downloading huggingface_hub-0.25.2-py3-none-any.whl (436 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.6/436.6 kB 25.9 MB/s eta 0:00:00
# Downloading python_multipart-0.0.12-py3-none-any.whl (23 kB)
# Downloading ruff-0.6.9-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 51.0 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading uvicorn-0.31.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 4.8 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading starlette-0.39.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.1 MB/s eta 0:00:00
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: pydub, websockets, uvicorn, tomlkit, semantic-version, ruff, python-multipart, ffmpy, aiofiles, starlette, huggingface-hub, gradio-client, fastapi, gradio
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.24.7
#     Uninstalling huggingface-hub-0.24.7:
#       Successfully uninstalled huggingface-hub-0.24.7
# Successfully installed aiofiles-23.2.1 fastapi-0.115.2 ffmpy-0.4.0 gradio-5.0.2 gradio-client-1.4.0 huggingface-hub-0.25.2 pydub-0.25.1 python-multipart-0.0.12 ruff-0.6.9 semantic-version-2.10.0 starlette-0.39.2 tomlkit-0.12.0 uvicorn-0.31.1 websockets-12.0

# %%
import gradio as gr

def generate_query(user_input):
    query_creation_messages = []

    template =  """
    You are a SQL expert skilled in writing complex queries for BigQuery. You will be given a user's request in plain text, describing the data they need to extract from the database. Your task is to convert the user's text input into a valid SQL query to retrieve the relevant data from the database.

    To help you construct accurate queries, you will be provided with:
    - A detailed overview of the database, including its schema, relationships between the tables, and explanations of each table and its fields.
    - The user's intent, extracted entities, and recommended tables based on their input.

    """

    system_message_prompt = SystemMessagePromptTemplate.from_template(template)
    query_creation_messages.append(system_message_prompt)

    human_template = """Use this information to generate a correct SQL query that meets the user's requirements:

    Northwind Traders Database Information:
    --------------
    Database Overview : {overview}\n
    Database Schema : {schema}\n
    Database Relationships : {relationships}
    Detailed Descriptions of Tables and Fields : {descriptions}

    User Query:
    -----------
    {user_query}


    Input Parameters:
    -----------------
    INTENT: {intent}
    EXTRACTED_ENTITIES: {entities}
    RECOMMENDED_MAPPED_TABLES: {mapping}

    NOTE : The database name in BigQuery is 'northwind_dataset'

    """

    human_message = HumanMessagePromptTemplate.from_template(human_template)
    query_creation_messages.append(human_message)

    chat_prompt = ChatPromptTemplate.from_messages(query_creation_messages)

    request = chat_prompt.format_prompt(intent=intent,
                                        entities=entities,
                                        mapping=mapping,
                                        user_query=user_input,
                                        overview = db_overview,
                                        schema = schema,
                                        relationships = relationships,
                                        descriptions = table_fields_descriptions).to_messages()

    query_generation_response = llm(request)

    llm_response = query_generation_response.content
    filtered_query = llm_response.strip().replace("sql", "").replace("", "").strip()
    filtered_query = filtered_query.replace("`","")


    client = bigquery.Client()

    query_job = client.query(filtered_query)

    # Get the result and display it
    results = query_job.result()

    df= results.to_dataframe()

    return df



demo = gr.Interface(
    fn=generate_query,
    inputs=gr.Text(label="Enter Query", info="Please explain in plain text, what data you would like to retrieve"),
    outputs=[gr.DataFrame(df)],
)

if __name__ == "__main__":
    demo.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://94027ddaac29ca406e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://94027ddaac29ca406e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
intent_examples
# Out:
#                                                Prompt  \
# 0   Show me all orders placed by customer "Alfreds...
# 1   I need the list of orders from "Around the Hor...
# 2   Can you retrieve orders made by "Berglunds sna...
# 3   Fetch all orders for "Blauer See Delikatessen"...
# 4   Give me the orders from "Bon app'" in the last...
# 5         Who are our top 5 customers by total sales?
# 6   List the customers with the highest order valu...
# 7   Which customers have spent the most with us in...
# 8   Show me the top 10 customers in terms of total...
# 9   Find out which customers generated the most re...
# 10  What's the total sales amount for each month i...
# 11  Provide a monthly breakdown of total sales for...
# 12        How much did we sell in each month of 2023?
# 13  Show me the total sales figures per month for ...
# 14  I'd like to see our monthly sales totals for 2...
# 15  In which month did we ship the most orders in ...
# 16    When was our busiest shipping period this year?
# 17  Identify the months with the highest number of...
# 18  Which month had the greatest number of orders ...
# 19  Find out during which period we shipped the mo...
# 20     How many products do we have in each category?
# 21  Provide a count of products grouped by their c...
# 22  List the number of products in each product ca...
# 23  Can you show me how many items are in each cat...
# 24  Give me a breakdown of product counts per cate...
# 25         Which products are currently out of stock?
# 26      List all items that have zero units in stock.
# 27  Show me the products that are not available ri...
# 28       Find the products that are out of inventory.
# 29        What products are we currently sold out of?
# 30  Who are the employees working in the Seattle r...
# 31           Show me all employees located in London.
# 32       Provide a list of employees by their region.
# 33  Which employees are assigned to the Eastern re...
# 34  List employees along with the regions they cover.
# 35  Give me contact details for the supplier "Exot...
# 36             I need the address of "Tokyo Traders".
# 37            Show me the suppliers based in the USA.
# 38  List all suppliers along with their contact na...
# 39  Who supplies "Aniseed Syrup" and how can we co...
# 40             Which products have been discontinued?
# 41  Show me all items that are no longer available...
# 42  List the discontinued products from our invent...
# 43              Find products marked as discontinued.
# 44             What products have we stopped selling?
# 45  Which products have stock levels below their r...
# 46           Show me items that need to be reordered.
# 47  List products where units in stock are less th...
# 48       Identify products with low inventory levels.
# 49            What products are running low in stock?
#
#                                   Intent
# 0   RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 1   RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 2   RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 3   RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 4   RETRIEVE_ORDERS_BY_CUSTOMER_AND_DATE
# 5        IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 6        IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 7        IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 8        IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 9        IDENTIFY_TOP_CUSTOMERS_BY_SALES
# 10       CALCULATE_TOTAL_SALES_PER_MONTH
# 11       CALCULATE_TOTAL_SALES_PER_MONTH
# 12       CALCULATE_TOTAL_SALES_PER_MONTH
# 13       CALCULATE_TOTAL_SALES_PER_MONTH
# 14       CALCULATE_TOTAL_SALES_PER_MONTH
# 15            FIND_PEAK_SHIPMENT_PERIODS
# 16            FIND_PEAK_SHIPMENT_PERIODS
# 17            FIND_PEAK_SHIPMENT_PERIODS
# 18            FIND_PEAK_SHIPMENT_PERIODS
# 19            FIND_PEAK_SHIPMENT_PERIODS
# 20  GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY
# 21  GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY
# 22  GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY
# 23  GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY
# 24  GROUP_AND_COUNT_PRODUCTS_BY_CATEGORY
# 25        IDENTIFY_OUT_OF_STOCK_PRODUCTS
# 26        IDENTIFY_OUT_OF_STOCK_PRODUCTS
# 27        IDENTIFY_OUT_OF_STOCK_PRODUCTS
# 28        IDENTIFY_OUT_OF_STOCK_PRODUCTS
# 29        IDENTIFY_OUT_OF_STOCK_PRODUCTS
# 30              LIST_EMPLOYEES_BY_REGION
# 31              LIST_EMPLOYEES_BY_REGION
# 32              LIST_EMPLOYEES_BY_REGION
# 33              LIST_EMPLOYEES_BY_REGION
# 34              LIST_EMPLOYEES_BY_REGION
# 35              GET_SUPPLIER_INFORMATION
# 36              GET_SUPPLIER_INFORMATION
# 37              GET_SUPPLIER_INFORMATION
# 38              GET_SUPPLIER_INFORMATION
# 39              GET_SUPPLIER_INFORMATION
# 40            FIND_DISCONTINUED_PRODUCTS
# 41            FIND_DISCONTINUED_PRODUCTS
# 42            FIND_DISCONTINUED_PRODUCTS
# 43            FIND_DISCONTINUED_PRODUCTS
# 44            FIND_DISCONTINUED_PRODUCTS
# 45          FIND_PRODUCTS_WITH_LOW_STOCK
# 46          FIND_PRODUCTS_WITH_LOW_STOCK
# 47          FIND_PRODUCTS_WITH_LOW_STOCK
# 48          FIND_PRODUCTS_WITH_LOW_STOCK
# 49          FIND_PRODUCTS_WITH_LOW_STOCK
