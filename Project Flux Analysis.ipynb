# %% [markdown]
# # Imports

# %%
# !pip install pypdf2
# Out:
# Requirement already satisfied: pypdf2 in /Users/rak/opt/anaconda3/lib/python3.9/site-packages (2.11.2)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /Users/rak/opt/anaconda3/lib/python3.9/site-packages (from pypdf2) (4.1.1)

# %%
pip install pycryptodome==3.15.0
# Out:
# Requirement already satisfied: pycryptodome==3.15.0 in /Users/rak/opt/anaconda3/lib/python3.9/site-packages (3.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyPDF2==2.11.2
# Out:
# Requirement already satisfied: PyPDF2==2.11.2 in /Users/rak/opt/anaconda3/lib/python3.9/site-packages (2.11.2)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /Users/rak/opt/anaconda3/lib/python3.9/site-packages (from PyPDF2==2.11.2) (4.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from PyPDF2 import PdfFileReader
import io
import seaborn as sns
import matplotlib.pyplot as plt
from threading import Thread

# %% [markdown]
# # Initialization

# %%
df_stb = pd.read_csv('sustainability_pdf.csv')
df_wrd = pd.read_csv('keywords.csv')
df_stb_news = pd.read_csv('sustainability_news.csv')

# %%
df_stb = df_stb[df_stb["Sustainability report : "] == True]
df_stb.drop(["No: ", "Sustainability report : ", "Unnamed: 4", "Unnamed: 5"], axis=1, inplace=True)
df_stb["Links/Pdf : "] = df_stb["Links/Pdf : "].str.replace(" ", "")

df_stb_news.drop(["No", "Purpose"], axis=1, inplace=True)
df_stb_news.rename(columns={"Link":"Links/Pdf : ", "Company":"Companies :"}, inplace=True)

# %%
df_stb_news.head()
# Out:
#           Companies :                                       Links/Pdf :
# 0        Google Cloud  https://cloud.google.com/blog/topics/sustainab...
# 1  Schneider Electric  https://www.eco-business.com/press-releases/sc...
# 2                GoTo    https://www.techinasia.com/decarbonization-goto
# 3                Grab  https://greennetwork.asia/news/grab-declares-a...
# 4         RDA & STACS  https://finance.yahoo.com/news/singapores-data...

# %%
df_stb.head()
# Out:
#   Companies :                                       Links/Pdf :
# 0       Apple  https://www.apple.com/environment/pdf/Apple_En...
# 1         PwC  https://www.pwc.com/sg/en/publications/assets/...
# 2         DBS  https://www.dbs.com/iwov-resources/images/sust...
# 3        Grab  https://sustainability2021.grab.com/sg/docs/gr...
# 4     Singtel  https://www.singtel.com/content/dam/singtel/ab...

# %%
df_wrd = df_wrd[["KEYWORD", "TIER"]]
df_wrd.KEYWORD = df_wrd.KEYWORD.str.lower()

# %%
df_wrd.head(5)
# Out:
#                    KEYWORD  TIER
# 0            carbon offset     3
# 1             digital twin     3
# 2              energy used     3
# 3  environmental footprint     3
# 4            it operations     3

# %% [markdown]
# # Scraping

# %%
def scrape(url, dict, key):
    headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'}
    
    response = requests.get(url, headers=headers)
    content_type = response.headers.get('content-type')
    if response.status_code != 200:
        print("error in", url)
        return

    # Scraping PDF
    if 'application/pdf' in content_type or 'application/xml' in content_type:
        with io.BytesIO(response.content) as f:
            pdf = PdfFileReader(f, strict=False)
            words = []
            for i in range(pdf.getNumPages()):
                words.extend(pdf.getPage(i).extract_text().lower().split())
            dict[key] = ' '.join(words)
    
    # Scraping html
    elif 'text/html' in content_type:
        soup = BeautifulSoup(response.content, "html.parser")
        dict[key] = ' '.join(soup.get_text().split())

# %%
def process_keywords(words, df_kywrd, tier):
    tier_count = 0
    kywrd = df_kywrd[df_kywrd.TIER == tier]["KEYWORD"]
    for wrd in kywrd:
        tier_count += words.count(wrd)
    return tier_count

# %%
# Score
# Tier 1: 3
# Tier 2: 2
# Tier 3: 1
def process_web(df_main, df_keyword):
    new_df = df_main.copy(deep=True)
    # Using multiThreading
    temp_dict = {}
    all_threads = []
    for i, j in new_df.iterrows():
        t = Thread(target=scrape, args=(df_main["Links/Pdf : "][i], temp_dict, i))
        t.start()
        all_threads.append(t)

    # Waiting for all threads to finish
    for thread in all_threads:
        thread.join()    

    try:
        new_df["Words"] = list(i[1] for i in sorted(temp_dict.items(), key=lambda x: x[0]))
        for i in range(1, 4):
            new_df[f"Tier {i} Count"] = new_df["Words"].apply(process_keywords, df_kywrd=df_keyword, tier=i)
        
        new_df["Score"] =  new_df.apply(
            lambda x: x['Tier 1 Count']*3+x['Tier 2 Count']*2+x['Tier 3 Count']*1, axis=1)
    except:
        print("check if the link is working")
        return
    
    return new_df

# %%
data = process_web(df_stb[:10], df_wrd)

# %%
# Scraping pdf

data.sort_values('Score', ascending=False)
data.groupby(['Companies :']).agg(lambda x : x.sum() if x.dtype=='int64' else ' '.join(x))
# Out:
#                                                            Links/Pdf :   \
# Companies :
# Apple                 https://www.apple.com/environment/pdf/Apple_En...
# Changi Airport Group  https://www.changiairport.com/content/dam/caco...
# DBS                   https://www.dbs.com/iwov-resources/images/sust...
# Foodpanda             https://www.foodpanda.com/wp-content/uploads/2...
# GovTech               https://www.tech.gov.sg/files/media/corporate-...
# Grab                  https://sustainability2021.grab.com/sg/docs/gr...
# PwC                   https://www.pwc.com/sg/en/publications/assets/...
# Sea                   https://cdn.sea.com/webmain/static/resource/se...
# Singapore Airlines    https://www.singaporeair.com/saar5/pdf/Investo...
# Singtel               https://www.singtel.com/content/dam/singtel/ab...
#
#                                                                   Words  \
# Companies :
# Apple                 covering fiscal year 2021environmental progres...
# Changi Airport Group  forging a sustainable changi sustainability re...
# DBS                   empowering a sustainable futuredbs group holdi...
# Foodpanda             foodpanda social impact report 2021 19contents...
# GovTech               annualreport20212022annualreport20212022 advan...
# Grab                  millions of new beginnings esg report 2021 tab...
# PwC                   sustainability report pwc singapore – financia...
# Sea                   2021 sea sustainability report what’s inside 2...
# Singapore Airlines    singapore airlines is a global company dedicat...
# Singtel               sustainability report 2022empower every genera...
#
#                       Tier 1 Count  Tier 2 Count  Tier 3 Count  Score
# Companies :
# Apple                          445           206           249   1996
# Changi Airport Group           215            60             9    774
# DBS                            552           113            31   1913
# Foodpanda                       13             4             0     47
# GovTech                          2             4             1     15
# Grab                           199            53            17    720
# PwC                             72            11             0    238
# Sea                             66             7             1    213
# Singapore Airlines              97            42            12    387
# Singtel                        367            86            23   1296

# %%
# Scraping Web
data_2 = process_web(df_stb_news, df_wrd)
data_2.sort_values('Score', ascending=False)
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
#            Companies :                                       Links/Pdf :   \
# 6            Microsoft  https://blogs.microsoft.com/blog/2020/01/16/mi...
# 10               Apple  https://www.apple.com/newsroom/2022/10/apple-c...
# 1   Schneider Electric  https://www.eco-business.com/press-releases/sc...
# 15                OCBC  https://www.ocbc.com/group/media/release/2022/...
# 3                 Grab  https://greennetwork.asia/news/grab-declares-a...
# 9           Sony Group  https://www.sony.com/en/SonyInfo/News/Press/20...
# 12    Temasek Holdings  https://www.temasek.com.sg/en/news-and-resourc...
# 7                  IBM  https://newsroom.ibm.com/2021-02-16-IBM-Commit...
# 8             JPMorgan  https://www.jpmorganchase.com/news-stories/jpm...
# 13           Foodpanda  https://www.eco-business.com/press-releases/fo...
# 4          RDA & STACS  https://finance.yahoo.com/news/singapores-data...
# 5                  DBS  https://esgnews.com/singapores-dbs-first-bank-...
# 0         Google Cloud  https://cloud.google.com/blog/topics/sustainab...
# 11                 UOB  https://www.uobgroup.com/uobgroup/newsroom/202...
# 2                 GoTo    https://www.techinasia.com/decarbonization-goto
# 14             Singtel  https://www.singtel.com/about-us/media-centre/...
#
#                                                 Words  Tier 1 Count  \
# 6   Microsoft will be carbon negative by 2030 - Th...            29
# 10  Apple calls on global supply chain to decarbon...            18
# 1   Schneider Electric launches SME kickstarter de...            25
# 15  ocbc-to-invest-25million-in-decarbonisation Ab...            16
# 3   Grab Declares a Commitment to Sustainability w...             9
# 9   Sony Group Portal - Sony accelerates target to...             6
# 12  Temasek launches GenZero, an investment platfo...            12
# 7   IBM Commits To Net Zero Greenhouse Gas Emissio...            12
# 8   JPMorgan Chase Releases Carbon Reduction Targe...             8
# 13  Foodpanda launches 'Green Label' restaurant ce...            12
# 4   Singapore's data centre industry to be digital...            11
# 5   Singapore’s DBS First Bank To Announce Decarbo...             7
# 0   Google releases carbon-free energy percentage ...             6
# 11  UOB commits to 2050 net zero targets to suppor...             4
# 2   Tech in Asia - Connecting Asia's startup ecosy...             0
# 14  Singtel partners Ericsson to deploy Singapore’...             0
#
#     Tier 2 Count  Tier 3 Count  Score
# 6             25             0    137
# 10            18             0     90
# 1              4             1     84
# 15            13             3     77
# 3              9             2     47
# 9             11             6     46
# 12             5             0     46
# 7              4             0     44
# 8              9             0     42
# 13             2             1     41
# 4              0             4     37
# 5              4             0     29
# 0              0             0     18
# 11             1             0     14
# 2              0             0      0
# 14             0             0      0

# %%
combined_data = pd.concat([data, data_2])
final_data = combined_data.groupby(['Companies :'], as_index=False).agg(lambda x : x.sum() if x.dtype=='int64' else ' '.join(x)).sort_values('Score', ascending=False)
final_data
# Out:
#              Companies :                                       Links/Pdf :   \
# 0                  Apple  https://www.apple.com/environment/pdf/Apple_En...
# 2                    DBS  https://www.dbs.com/iwov-resources/images/sust...
# 17               Singtel  https://www.singtel.com/content/dam/singtel/ab...
# 1   Changi Airport Group  https://www.changiairport.com/content/dam/caco...
# 7                   Grab  https://sustainability2021.grab.com/sg/docs/gr...
# 16    Singapore Airlines  https://www.singaporeair.com/saar5/pdf/Investo...
# 12                   PwC  https://www.pwc.com/sg/en/publications/assets/...
# 15                   Sea  https://cdn.sea.com/webmain/static/resource/se...
# 10             Microsoft  https://blogs.microsoft.com/blog/2020/01/16/mi...
# 3              Foodpanda  https://www.foodpanda.com/wp-content/uploads/2...
# 14    Schneider Electric  https://www.eco-business.com/press-releases/sc...
# 11                  OCBC  https://www.ocbc.com/group/media/release/2022/...
# 18            Sony Group  https://www.sony.com/en/SonyInfo/News/Press/20...
# 19      Temasek Holdings  https://www.temasek.com.sg/en/news-and-resourc...
# 8                    IBM  https://newsroom.ibm.com/2021-02-16-IBM-Commit...
# 9               JPMorgan  https://www.jpmorganchase.com/news-stories/jpm...
# 13           RDA & STACS  https://finance.yahoo.com/news/singapores-data...
# 5           Google Cloud  https://cloud.google.com/blog/topics/sustainab...
# 6                GovTech  https://www.tech.gov.sg/files/media/corporate-...
# 20                   UOB  https://www.uobgroup.com/uobgroup/newsroom/202...
# 4                   GoTo    https://www.techinasia.com/decarbonization-goto
#
#                                                 Words  Tier 1 Count  \
# 0   covering fiscal year 2021environmental progres...           463
# 2   empowering a sustainable futuredbs group holdi...           559
# 17  sustainability report 2022empower every genera...           367
# 1   forging a sustainable changi sustainability re...           215
# 7   millions of new beginnings esg report 2021 tab...           208
# 16  singapore airlines is a global company dedicat...            97
# 12  sustainability report pwc singapore – financia...            72
# 15  2021 sea sustainability report what’s inside 2...            66
# 10  Microsoft will be carbon negative by 2030 - Th...            29
# 3   foodpanda social impact report 2021 19contents...            25
# 14  Schneider Electric launches SME kickstarter de...            25
# 11  ocbc-to-invest-25million-in-decarbonisation Ab...            16
# 18  Sony Group Portal - Sony accelerates target to...             6
# 19  Temasek launches GenZero, an investment platfo...            12
# 8   IBM Commits To Net Zero Greenhouse Gas Emissio...            12
# 9   JPMorgan Chase Releases Carbon Reduction Targe...             8
# 13  Singapore's data centre industry to be digital...            11
# 5   Google releases carbon-free energy percentage ...             6
# 6   annualreport20212022annualreport20212022 advan...             2
# 20  UOB commits to 2050 net zero targets to suppor...             4
# 4   Tech in Asia - Connecting Asia's startup ecosy...             0
#
#     Tier 2 Count  Tier 3 Count  Score
# 0            224           249   2086
# 2            117            31   1942
# 17            86            23   1296
# 1             60             9    774
# 7             62            19    767
# 16            42            12    387
# 12            11             0    238
# 15             7             1    213
# 10            25             0    137
# 3              6             1     88
# 14             4             1     84
# 11            13             3     77
# 18            11             6     46
# 19             5             0     46
# 8              4             0     44
# 9              9             0     42
# 13             0             4     37
# 5              0             0     18
# 6              4             1     15
# 20             1             0     14
# 4              0             0      0

# %% [markdown]
# # Vizualisation

# %%
fig, ax = plt.subplots(figsize=(40, 10))
sns.set_context("notebook", font_scale=1.5)
processed_data = pd.melt(final_data[:10].drop(["Links/Pdf : ", "Words", "Score"], axis=1), id_vars="Companies :")
sns.barplot(data=processed_data, x="Companies :", y="value", hue="variable", ax=ax)
plt.title("Word count in each company")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 fig, ax = plt.subplots(figsize=(40, 10))
#       2 sns.set_context("notebook", font_scale=1.5)
#       3 processed_data = pd.melt(final_data[:10].drop(["Links/Pdf : ", "Words", "Score"], axis=1), id_vars="Companies :")
#
# NameError: name 'plt' is not defined

# %%
fig, ax = plt.subplots(figsize=(40, 8))
sns.set_context("notebook", font_scale=2.5)
sns.barplot(data=final_data[:10].sort_values('Score', ascending=False), 
            x="Companies :", y="Score", ax=ax)
plt.title("Companies Score")
plt.show()
